# %% [markdown]
# ## 🧱 Özel Ortam
#
# ---
#
# Bu görevde, derste örnek olarak kullanılan **ızgara tabanlı navigasyon ortamının** birebir aynısını tasarlayıp uygulayacaksınız.
#
# - Ajan ızgaranın bir köşesinde başlar.
# - Amaç karşı köşeye ulaşmaktır.
# - Izgarada ajanın kaçınması gereken engeller veya "delikler" bulunabilir.
#
# ---
#
# ### 🎯 Amaçlar
#
# - 📐 **Ortamı Tanımlayın**: ajanın başlangıçtan hedefe doğru hareket ettiği bir ızgara dünyası oluşturun.
# - ⚙️ **Ortam Dinamiklerini Uygulayın**: hareket ve ödül ataması kurallarını programlayın (örn. deliklere düşmek için ceza, hedefe ulaşmak için ödül).
# - 👁️ **Gözlem ve Eylemleri Ayarlayın**:
#     - **Gözlem alanı** → Ajanın algıladığı şeyler (örn. ızgaradaki pozisyonu)
#     - **Eylem alanı** → Ajanın yapabileceği şeyler (örn. yukarı, aşağı, sola, sağa hareket)
# - 🖼️ **Render Metodu Ekleyin**: ortamı görselleştirmek için `.render()` fonksiyonu ekleyin — hata ayıklama ve ajanın davranışını anlama için faydalıdır.
# - 🧩 **Özel Özellikler Ekleyin**: derste ele alınan engeller, çukurlar veya diğer özellikleri dahil ederek ortamınızı daha dinamik ve gerçekçi hale getirin.

# %% [markdown]
# ---
# Bu görev için ihtiyacımız olan tüm paketleri içe aktararak başlayalım:

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from typing import Optional, Dict, Tuple


import gymnasium as gym
from gymnasium import spaces
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import DQN
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env

# %% [markdown]
# ---
#
# ### 🧩 Bölüm 1: Özel Ortam Sınıfı Oluşturma
#
# Bu bölümde, kısmen yazılmış bir sınıfı tamamlayarak özel ortamınızı uygulayacaksınız.
# Yapı, Gymnasium'un ortam oluşturma için standart formatını takip eder.
#
# ### 🛠️ Yapacaklarınız
#
# - Bazı temel metotları önceden yazılmış bir şablon sağlanmıştır.
# - `# CODE HERE` yazdığını gördüğünüz her yerde, eksik mantığı doldurmanız gerekir.
# - Her adımda size rehberlik etmesi için satır içi ipuçları verilmiştir.
#
# ### 🎯 Hedefiniz
#
# - Sınıfı gerçek bir Gymnasium ortamı gibi davranacak şekilde tamamlayın.
# - Şunları yapmalı:
#   - Geçerli bir gözlem ve eylem alanı tanımlamalı
#   - Ajan hareketini ve geçişleri ele almalı
#   - Ödülleri döndürmeli ve `done` bayraklarını uygun şekilde güncellemeli
#   - Çalışan bir `.reset()` ve `.step()` metodu içermeli
#   - İsteğe bağlı olarak görselleştirme için basit bir `.render()` içermeli
#
# 🧠 Her metodu anlamak için zaman ayırın — özellikle durum geçişlerinin ve ödüllerin nasıl yönetildiğini. RL ortamları burada canlanır.
#
# 📚 Ortam yapısı ve en iyi uygulamalar hakkında ayrıntılı adımlar için resmi [Gymnasium özel ortam kılavuzuna](https://gymnasium.farama.org/introduction/create_custom_env/) başvurun.

# %%
class CustomGridEnv(gym.Env):
    metadata = {'render_modes': ['human']}

    def __init__(self):
        # Grid size (3x3)
        self.size = 3
        
        # Define the action space: 4 possible actions (right, up, left, down)
        self.action_space = spaces.Discrete(4)
        
        # Initial position of the agent (top-left corner)
        self.agent_position = np.array([0, 0], dtype=np.int32)
        
        # Position of the target (bottom-right corner)
        self.goal_position = np.array([2, 2], dtype=np.int32)
        
        # Position of the hole (bottom middle)
        self.hole_position = np.array([2, 1], dtype=np.int32)
        
        # Mapping from actions to grid movements
        # 0: right, 1: up, 2: left, 3: down
        self.action_to_direction = {
            0: np.array([0, 1]),   # right
            1: np.array([-1, 0]),  # up
            2: np.array([0, -1]),  # left
            3: np.array([1, 0])    # down
        }

        # Define the observation space using dictionary spaces for agent and target locations
        self.observation_space = spaces.Dict({
            "agent": spaces.Box(low=0, high=self.size - 1, shape=(2,), dtype=np.int32),
            "target": spaces.Box(low=0, high=self.size - 1, shape=(2,), dtype=np.int32),
        })

    def reset(self, seed: Optional[int] = None, options: Optional[Dict] = None) -> Tuple[Dict, Dict]:
        # Reset the environment for a new episode
        super().reset(seed=seed)

        # Reset the agent's position to the starting position (top-left corner)
        self.agent_position = np.array([0, 0], dtype=np.int32)

        # Goal position remains constant
        self.goal_position = np.array([2, 2], dtype=np.int32)

        # Generate observation and info for the current state
        observation = self._get_obs()
        info = self._get_info()
        return observation, info

    def _get_obs(self):
        # Return current observation of agent and target positions
        return {
            "agent": self.agent_position.copy(),
            "target": self.goal_position.copy()
        }

    def _get_info(self):
        # Compute the Manhattan distance between the agent and the target
        distance = np.sum(np.abs(self.agent_position - self.goal_position))
        return {"distance": distance}

    def step(self, action):
        # Apply the action to change the agent_position
        # Convert action to int if it's a numpy array (for compatibility with DQN)
        if isinstance(action, np.ndarray):
            action = int(action)
        
        direction = self.action_to_direction[action]
        new_position = self.agent_position + direction
        
        # Ensure the agent stays within the grid boundaries
        new_position = np.clip(new_position, 0, self.size - 1)
        self.agent_position = new_position
        
        # Initialize reward and done flag
        reward = 0
        done = False
        
        # Check if agent fell in hole
        if np.array_equal(self.agent_position, self.hole_position):
            reward = -10
            done = True
        # Check if agent reached goal
        elif np.array_equal(self.agent_position, self.goal_position):
            reward = 10
            done = True
        # Otherwise, give small negative reward for each step
        else:
            reward = -1

        # Collect observation and info about the current state
        observation = self._get_obs()
        info = self._get_info()
        return observation, reward, done, False, info  # 'truncated' is always False

    def render(self, mode='human'):

        # Visual representation of the grid
        grid = np.full((self.size, self.size), fill_value=' ')

        # Get x and y indexes for agent_position, goal_position, and hole_position
        agent_x, agent_y = self.agent_position[0], self.agent_position[1]
        goal_x, goal_y = self.goal_position[0], self.goal_position[1]
        hole_x, hole_y = self.hole_position[0], self.hole_position[1]

        grid[agent_x][agent_y] = 'A'
        grid[goal_x][goal_y] = 'G'
        grid[hole_x][hole_y] = 'H'

        # Print the grid with borders
        print("+---" * self.size + "+")
        for row in grid:
            print("|" + "|".join(f" {cell} " for cell in row) + "|")
            print("+---" * self.size + "+")

# %% [markdown]
# 👇 Önceki bölümü doğru tamamladığınızı test etmek için aşağıdaki hücreyi çalıştırın. Doğru yaptıysanız, ajanın bir bölümün sonu olan hedefe veya deliğe ulaşana kadar ortamınızda rastgele hareket ettiğini göreceksiniz.

# %%
# Create an instance of the custom environment
env = CustomGridEnv()

# Reset the environment to its initial state and get the initial observation and info
obs, info = env.reset()
print("Initial Observation:", obs)  # Display the initial position of the agent and the target
print("Initial Info:", info)  # Display additional information such as the distance from the target

# Loop through a maximum of 100 steps
for _ in range(100):
    action = env.action_space.sample()  # Randomly sample an action from the action space
    obs, reward, done, info, _ = env.step(action)  # Apply the action and get the results
    env.render()  # Render the current state of the environment to visualize the agent's position

    # Print the current state, reward received, whether the episode is done, and any additional info
    print(f"State: {obs}, Reward: {reward}, Done: {done}, Info: {info}")

    # If the episode is finished (agent reached the goal or fell into a hole), exit the loop
    if done:
        break
# Out:
# Initial Observation: {'agent': array([0, 0], dtype=int32), 'target': array([2, 2], dtype=int32)}
# Initial Info: {'distance': 4}
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# State: {'agent': array([0, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: False
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# State: {'agent': array([0, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: False
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: False
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A | H | G |
# +---+---+---+
# State: {'agent': array([2, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: False
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# State: {'agent': array([2, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -10, Done: True, Info: False

# %% [markdown]
# ---
# ## Bölüm 2: DQN Eğitimi 🤖
#
# Bu bölümde, özel ortamınızı başlatacak ve Stable Baselines3 kütüphanesini kullanarak bir DQN ajanı ile etkileşim için hazırlayacaksınız. Temel görev, ortamınızın kütüphanenin gereksinimleriyle uyumlu olduğundan emin olmaktır, bu da onu uygun şekilde sarmalamayı içerir.
#
# #### 📝 İzlenecek adımlar
#
# 1. 🧱 **Özel Ortamı Başlatın**: özel ortam sınıfınızın bir örneğini oluşturun.
# 2. 🔁 **SB3 Uyumluluğunu Sağlayın**: Stable Baselines3'ten `make_vec_env` fonksiyonunu kullanarak ortamınızı sarın, böylece kütüphanenin vektörleştirilmiş ortam gereksinimleriyle uyumlu hale getirin.
# 3. ⚙️ **DQN Ajanını Yapılandırın ve Eğitin**: DQN ajanını uygun hiperparametrelerle kurun ve ortamınızda eğitin.
# 4. 📊 **Eğitim İlerlemesini İzleyin**: Ajanın öğrenme ilerlemesini ve performansını zaman içinde gözlemlemek için günlükleme ve izleme uygulayın.
# 5. 💾 **Modeli kaydedin**: Eğitim sonrasında modelinizi kaydedin.

# %%
# Create the custom environment
env = CustomGridEnv()

# Wrap the environment using make_vec_env for compatibility with Stable Baselines3
# This creates a vectorized environment that can be used with DQN
vec_env = make_vec_env(lambda: CustomGridEnv(), n_envs=1)

# Create and train the DQN agent
# DQN is a deep reinforcement learning algorithm that learns to maximize cumulative rewards
model = DQN(
    "MultiInputPolicy",  # Use MultiInputPolicy for Dict observation spaces
    vec_env,
    verbose=1,
    learning_rate=1e-3,
    buffer_size=10000,
    learning_starts=1000,
    batch_size=32,
    gamma=0.99,
    exploration_fraction=0.1,
    exploration_initial_eps=1.0,
    exploration_final_eps=0.05,
    target_update_interval=1000,
    train_freq=4
)

# Train the model for 50000 timesteps
print("Training DQN agent...")
model.learn(total_timesteps=50000)

# Save the trained model
model.save("dqn_grid_env_model")
print("Model saved successfully!")
# Out:
# Using cpu device
# Training DQN agent...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | -20      |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 11941    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 44       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 10824    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 112      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | -19.1    |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 10756    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 161      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | -22.5    |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 11789    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 276      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | -22.2    |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 11892    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 324      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | -19.7    |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 11416    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 377      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | -18.7    |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 11166    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 411      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 11267    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 524      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | -18.9    |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 11140    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 558      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | -18.3    |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 11356    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 612      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | -18.9    |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 11397    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 676      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | -19.2    |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 11297    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 729      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | -19      |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 11359    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 778      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | -19.1    |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 11490    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 864      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | -18.7    |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 11434    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 900      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | -18.6    |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 11553    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 977      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | -18.9    |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 7015     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1054     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.36     |
# |    n_updates        | 13       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | -18.8    |
# |    exploration_rate | 0.79     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 6249     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1106     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.639    |
# |    n_updates        | 26       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | -19.2    |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 5487     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1192     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.273    |
# |    n_updates        | 47       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | -19      |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 5283     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1221     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.335    |
# |    n_updates        | 55       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | -19      |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 4840     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1298     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.802    |
# |    n_updates        | 74       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | -19.4    |
# |    exploration_rate | 0.739    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 4563     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1373     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.917    |
# |    n_updates        | 93       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | -19.4    |
# |    exploration_rate | 0.723    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 4188     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1458     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.519    |
# |    n_updates        | 114      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | -19.6    |
# |    exploration_rate | 0.704    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 3979     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1560     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.776    |
# |    n_updates        | 139      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | -20      |
# |    exploration_rate | 0.684    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 3813     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1663     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.223    |
# |    n_updates        | 165      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | -19.7    |
# |    exploration_rate | 0.678    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 3754     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1696     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.221    |
# |    n_updates        | 173      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.3     |
# |    ep_rew_mean      | -19.1    |
# |    exploration_rate | 0.668    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 3561     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1746     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.609    |
# |    n_updates        | 186      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | -19      |
# |    exploration_rate | 0.661    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 3475     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1784     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.33     |
# |    n_updates        | 195      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | -18.4    |
# |    exploration_rate | 0.652    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 3427     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1832     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.697    |
# |    n_updates        | 207      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | -18.2    |
# |    exploration_rate | 0.645    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 3359     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1866     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.506    |
# |    n_updates        | 216      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | -18.4    |
# |    exploration_rate | 0.635    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 3233     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1919     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.836    |
# |    n_updates        | 229      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | -18.6    |
# |    exploration_rate | 0.621    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 3125     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1993     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.476    |
# |    n_updates        | 248      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | -18      |
# |    exploration_rate | 0.615    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 3076     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2027     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.695    |
# |    n_updates        | 256      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | -18.6    |
# |    exploration_rate | 0.606    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 3013     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2073     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.522    |
# |    n_updates        | 268      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | -19.4    |
# |    exploration_rate | 0.58     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 2897     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2211     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.631    |
# |    n_updates        | 302      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | -18.4    |
# |    exploration_rate | 0.575    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 2883     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2238     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.508    |
# |    n_updates        | 309      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | -17.6    |
# |    exploration_rate | 0.565    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 2809     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2288     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0106   |
# |    n_updates        | 321      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | -16.9    |
# |    exploration_rate | 0.557    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 2774     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2330     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.478    |
# |    n_updates        | 332      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | -16.3    |
# |    exploration_rate | 0.55     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 2747     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2371     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.41     |
# |    n_updates        | 342      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | -16      |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 2715     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2399     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.244    |
# |    n_updates        | 349      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | -15.2    |
# |    exploration_rate | 0.538    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 2699     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2434     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.824    |
# |    n_updates        | 358      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | -14.5    |
# |    exploration_rate | 0.532    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 2691     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2463     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.141    |
# |    n_updates        | 365      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | -13.9    |
# |    exploration_rate | 0.527    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 2663     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2492     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.04     |
# |    n_updates        | 372      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | -13      |
# |    exploration_rate | 0.522    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 2657     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2514     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.148    |
# |    n_updates        | 378      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | -12.5    |
# |    exploration_rate | 0.519    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 2641     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2532     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.831    |
# |    n_updates        | 382      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | -12.1    |
# |    exploration_rate | 0.516    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 2615     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2549     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.701    |
# |    n_updates        | 387      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | -11.2    |
# |    exploration_rate | 0.508    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 2581     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2592     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.589    |
# |    n_updates        | 397      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | -10.6    |
# |    exploration_rate | 0.499    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 2560     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2636     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.249    |
# |    n_updates        | 408      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | -9.6     |
# |    exploration_rate | 0.495    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 2547     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2660     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.661    |
# |    n_updates        | 414      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | -9.06    |
# |    exploration_rate | 0.489    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 2522     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2689     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.694    |
# |    n_updates        | 422      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | -9.07    |
# |    exploration_rate | 0.479    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 2506     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2743     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.442    |
# |    n_updates        | 435      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | -8.64    |
# |    exploration_rate | 0.474    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 2493     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2770     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.336    |
# |    n_updates        | 442      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | -7.88    |
# |    exploration_rate | 0.47     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 2483     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2792     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.344    |
# |    n_updates        | 447      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.83     |
# |    ep_rew_mean      | -7.23    |
# |    exploration_rate | 0.465    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 2467     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2815     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.324    |
# |    n_updates        | 453      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.76     |
# |    ep_rew_mean      | -6.76    |
# |    exploration_rate | 0.46     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 2452     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2842     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.62     |
# |    n_updates        | 460      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.68     |
# |    ep_rew_mean      | -6.68    |
# |    exploration_rate | 0.451    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 2432     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2887     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.575    |
# |    n_updates        | 471      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.26     |
# |    ep_rew_mean      | -5.86    |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 2408     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2919     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.259    |
# |    n_updates        | 479      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.56     |
# |    ep_rew_mean      | -5.56    |
# |    exploration_rate | 0.433    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 2374     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2983     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0662   |
# |    n_updates        | 495      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.44     |
# |    ep_rew_mean      | -4.84    |
# |    exploration_rate | 0.427    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 2358     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3017     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.518    |
# |    n_updates        | 504      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.61     |
# |    ep_rew_mean      | -3.81    |
# |    exploration_rate | 0.416    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 2343     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3072     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.584    |
# |    n_updates        | 517      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.63     |
# |    ep_rew_mean      | -4.03    |
# |    exploration_rate | 0.411    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 2333     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3101     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.362    |
# |    n_updates        | 525      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.36     |
# |    ep_rew_mean      | -3.76    |
# |    exploration_rate | 0.406    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 2318     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3124     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0571   |
# |    n_updates        | 530      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.23     |
# |    ep_rew_mean      | -3.83    |
# |    exploration_rate | 0.401    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 2299     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3153     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.853    |
# |    n_updates        | 538      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.01     |
# |    ep_rew_mean      | -3.61    |
# |    exploration_rate | 0.397    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 2289     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3172     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.13     |
# |    n_updates        | 542      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.6      |
# |    ep_rew_mean      | -3.8     |
# |    exploration_rate | 0.381    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 2271     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3259     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.511    |
# |    n_updates        | 564      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.49     |
# |    ep_rew_mean      | -3.69    |
# |    exploration_rate | 0.376    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 2265     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3283     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0312   |
# |    n_updates        | 570      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.42     |
# |    ep_rew_mean      | -3.42    |
# |    exploration_rate | 0.372    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 2255     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3305     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.514    |
# |    n_updates        | 576      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.41     |
# |    ep_rew_mean      | -3.21    |
# |    exploration_rate | 0.367    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 2246     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3333     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.513    |
# |    n_updates        | 583      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.47     |
# |    ep_rew_mean      | -2.87    |
# |    exploration_rate | 0.361    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 2246     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3361     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.268    |
# |    n_updates        | 590      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.59     |
# |    ep_rew_mean      | -2.79    |
# |    exploration_rate | 0.356    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 2238     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3391     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.99     |
# |    n_updates        | 597      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.63     |
# |    ep_rew_mean      | -2.23    |
# |    exploration_rate | 0.352    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 2228     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3412     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.479    |
# |    n_updates        | 602      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.53     |
# |    ep_rew_mean      | -2.13    |
# |    exploration_rate | 0.345    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 2218     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3445     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.255    |
# |    n_updates        | 611      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.27     |
# |    ep_rew_mean      | -1.67    |
# |    exploration_rate | 0.342    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 2215     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3463     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.499    |
# |    n_updates        | 615      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.21     |
# |    ep_rew_mean      | -1.41    |
# |    exploration_rate | 0.339    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 2209     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3481     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.2      |
# |    n_updates        | 620      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.17     |
# |    ep_rew_mean      | -0.57    |
# |    exploration_rate | 0.334    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 2205     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3506     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.249    |
# |    n_updates        | 626      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.85     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.33     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 2197     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3528     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.25     |
# |    n_updates        | 631      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.78     |
# |    ep_rew_mean      | -0.18    |
# |    exploration_rate | 0.326    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 2194     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3548     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.505    |
# |    n_updates        | 636      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.82     |
# |    ep_rew_mean      | -0.62    |
# |    exploration_rate | 0.321    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 2186     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3574     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.472    |
# |    n_updates        | 643      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.89     |
# |    ep_rew_mean      | -0.49    |
# |    exploration_rate | 0.315    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 2177     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3604     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.249    |
# |    n_updates        | 650      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.86     |
# |    ep_rew_mean      | -0.06    |
# |    exploration_rate | 0.311    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 2168     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3628     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.648    |
# |    n_updates        | 656      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.59     |
# |    ep_rew_mean      | 0.41     |
# |    exploration_rate | 0.307    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 2159     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3646     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.418    |
# |    n_updates        | 661      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.5      |
# |    ep_rew_mean      | 0.3      |
# |    exploration_rate | 0.303    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 2152     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3669     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.271    |
# |    n_updates        | 667      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.07     |
# |    ep_rew_mean      | 0.93     |
# |    exploration_rate | 0.299    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 2147     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3690     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.255    |
# |    n_updates        | 672      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.05     |
# |    ep_rew_mean      | 0.75     |
# |    exploration_rate | 0.293    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 2137     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3722     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.05     |
# |    n_updates        | 680      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.7      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.289    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 2126     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3742     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.435    |
# |    n_updates        | 685      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.63     |
# |    ep_rew_mean      | 1.77     |
# |    exploration_rate | 0.285    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 2119     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3764     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0103   |
# |    n_updates        | 690      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.6      |
# |    ep_rew_mean      | 1.6      |
# |    exploration_rate | 0.281    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 2114     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3784     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.688    |
# |    n_updates        | 695      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.72     |
# |    ep_rew_mean      | 1.28     |
# |    exploration_rate | 0.273    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 2085     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3825     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.497    |
# |    n_updates        | 706      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.68     |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 2084     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3840     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.568    |
# |    n_updates        | 709      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.02     |
# |    ep_rew_mean      | 1.98     |
# |    exploration_rate | 0.266    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 2079     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3861     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.22     |
# |    n_updates        | 715      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6        |
# |    ep_rew_mean      | 2        |
# |    exploration_rate | 0.262    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 2078     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3883     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.541    |
# |    n_updates        | 720      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.97     |
# |    ep_rew_mean      | 2.23     |
# |    exploration_rate | 0.259    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 2071     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3902     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0298   |
# |    n_updates        | 725      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.85     |
# |    ep_rew_mean      | 2.35     |
# |    exploration_rate | 0.256    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 2064     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3918     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.389    |
# |    n_updates        | 729      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.77     |
# |    ep_rew_mean      | 2.23     |
# |    exploration_rate | 0.252    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 2062     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3938     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.114    |
# |    n_updates        | 734      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.86     |
# |    ep_rew_mean      | 1.94     |
# |    exploration_rate | 0.244    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 2050     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3977     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.462    |
# |    n_updates        | 744      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.89     |
# |    ep_rew_mean      | 1.71     |
# |    exploration_rate | 0.24     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 2048     |
# |    time_elapsed     | 1        |
# ...
# |    total_timesteps  | 49494    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.53e-05 |
# |    n_updates        | 12123    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.3      |
# |    ep_rew_mean      | 6.7      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11124    |
# |    fps              | 936      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 49514    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.38e-05 |
# |    n_updates        | 12128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.31     |
# |    ep_rew_mean      | 6.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11128    |
# |    fps              | 936      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 49531    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.18e-05 |
# |    n_updates        | 12132    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.29     |
# |    ep_rew_mean      | 6.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11132    |
# |    fps              | 936      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 49547    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.42e-05 |
# |    n_updates        | 12136    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.3      |
# |    ep_rew_mean      | 6.7      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11136    |
# |    fps              | 936      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 49564    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.73e-05 |
# |    n_updates        | 12140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.3      |
# |    ep_rew_mean      | 6.7      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11140    |
# |    fps              | 936      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 49580    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 9.62e-06 |
# |    n_updates        | 12144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.29     |
# |    ep_rew_mean      | 6.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11144    |
# |    fps              | 936      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 49596    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000162 |
# |    n_updates        | 12148    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.27     |
# |    ep_rew_mean      | 6.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11148    |
# |    fps              | 936      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 49612    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000192 |
# |    n_updates        | 12152    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.25     |
# |    ep_rew_mean      | 6.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11152    |
# |    fps              | 936      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49628    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.31e-06 |
# |    n_updates        | 12156    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.25     |
# |    ep_rew_mean      | 6.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11156    |
# |    fps              | 936      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49644    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.06e-05 |
# |    n_updates        | 12160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.25     |
# |    ep_rew_mean      | 6.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11160    |
# |    fps              | 936      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49660    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000179 |
# |    n_updates        | 12164    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.21     |
# |    ep_rew_mean      | 6.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11164    |
# |    fps              | 936      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49676    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.08e-05 |
# |    n_updates        | 12168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.23     |
# |    ep_rew_mean      | 6.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11168    |
# |    fps              | 936      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49694    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.94e-05 |
# |    n_updates        | 12173    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.22     |
# |    ep_rew_mean      | 6.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11172    |
# |    fps              | 936      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49710    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.55e-06 |
# |    n_updates        | 12177    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.25     |
# |    ep_rew_mean      | 6.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11176    |
# |    fps              | 936      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49729    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.21e-06 |
# |    n_updates        | 12182    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.25     |
# |    ep_rew_mean      | 6.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11180    |
# |    fps              | 936      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49745    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.33e-05 |
# |    n_updates        | 12186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.23     |
# |    ep_rew_mean      | 6.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11184    |
# |    fps              | 936      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49763    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.72e-05 |
# |    n_updates        | 12190    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.24     |
# |    ep_rew_mean      | 6.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11188    |
# |    fps              | 936      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49780    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.61e-05 |
# |    n_updates        | 12194    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.22     |
# |    ep_rew_mean      | 6.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11192    |
# |    fps              | 935      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49796    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.25e-06 |
# |    n_updates        | 12198    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.18     |
# |    ep_rew_mean      | 6.82     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11196    |
# |    fps              | 936      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49812    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.98e-05 |
# |    n_updates        | 12202    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.19     |
# |    ep_rew_mean      | 6.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11200    |
# |    fps              | 936      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49829    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.41e-05 |
# |    n_updates        | 12207    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.19     |
# |    ep_rew_mean      | 6.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11204    |
# |    fps              | 936      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49845    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.5e-05  |
# |    n_updates        | 12211    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.18     |
# |    ep_rew_mean      | 6.82     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11208    |
# |    fps              | 936      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49861    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.11e-05 |
# |    n_updates        | 12215    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.18     |
# |    ep_rew_mean      | 6.82     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11212    |
# |    fps              | 935      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49877    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.65e-05 |
# |    n_updates        | 12219    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16     |
# |    ep_rew_mean      | 6.84     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11216    |
# |    fps              | 935      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49893    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.9e-07  |
# |    n_updates        | 12223    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.15     |
# |    ep_rew_mean      | 6.85     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11220    |
# |    fps              | 935      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49909    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.85e-05 |
# |    n_updates        | 12227    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12     |
# |    ep_rew_mean      | 6.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11224    |
# |    fps              | 935      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49926    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.01e-06 |
# |    n_updates        | 12231    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11     |
# |    ep_rew_mean      | 6.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11228    |
# |    fps              | 935      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49942    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.43e-05 |
# |    n_updates        | 12235    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13     |
# |    ep_rew_mean      | 6.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11232    |
# |    fps              | 935      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49960    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.14e-06 |
# |    n_updates        | 12239    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14     |
# |    ep_rew_mean      | 6.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11236    |
# |    fps              | 935      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49978    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.03e-05 |
# |    n_updates        | 12244    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.17     |
# |    ep_rew_mean      | 6.63     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11240    |
# |    fps              | 935      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49997    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.67e-05 |
# |    n_updates        | 12249    |
# ----------------------------------
# Model saved successfully!

# %% [markdown]
# ---
# ## 🎮 Bölüm 3: Eğitilmiş modelinizi kullanın
#
# Eğitilmiş DQN modelinizi yükleyecek ve ortamda karar vermek için kullanacaksınız, başlangıç noktasından hedefe delikleri kaçınarak nasıl gittiğini gözlemleyeceksiniz. Bu sadece eğitimin etkinliğini doğrulamanıza izin vermeyecek, aynı zamanda ajanın karar verme sürecini görsel olarak yorumlamanıza da olanak sağlayacaktır.
#
# ### İzlenecek adımlar 📝
# 1. 💾 **Eğitilmiş Modeli Yükleyin**: Eğitim aşamasında kaydedilen DQN modelini alın.
# 2. 🔄 **Ortamı Sıfırlayın**: Navigasyon görevini sıfırdan başlatmak için ortamı başlatın.
# 3. 🧠 **Navigasyon Simülasyonunu Çalıştırın**: Modeli kullanarak ortamın durumlarına dayalı eylemleri tahmin edin ve ajanın attığı her adımı görselleştirin.
# 4. 👀 **Her Adımı Görselleştirin**: Ajanın pozisyonunu, hedefi ve herhangi bir engeli veya deliği gösteren ızgaranın basit bir görselleştirmesini uygulayın.
# 5. 📝 **Ajan Davranışını Analiz Edin**: Ajanın hedefe ulaşma yeteneğini gözlemleyin ve not edin ve delikleri ne kadar etkili bir şekilde kaçındığını görün.
#
# Kodun bir kısmı zaten orada ve `# CODE HERE` yorumunu gördüğünüz her yerde kod doldurmanız gerekiyor. Başlamanız için bazı ipuçları bulacaksınız.

# %%
# Load the model
model = DQN.load("dqn_grid_env_model")

# Create a new environment for testing
env = CustomGridEnv()

# Reset the environment to the initial state and get the first observation
obs, info = env.reset()

for step in range(200):  # Loop through a maximum of 200 steps (or until the episode ends)
    # Use the model to predict the next action to be taken, based on the current observation
    # Execute the chosen action in the environment, receive the next state and reward, and check if the episode is done
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, done, truncated, info = env.step(action)


    # Initialize a 3x3 grid filled with spaces to represent the environment visually
    grid = np.full((3, 3), fill_value=' ')

    # Extract coordinates for the agent, goal, and hole using the current observation
    agent_x, agent_y = obs['agent'][0], obs['agent'][1]
    goal_x, goal_y = obs['target'][0], obs['target'][1]
    hole_x, hole_y = 2, 1  # The hole's position is fixed in the environment

    # Update the grid with the agent's, goal's, and hole's positions
    grid[agent_x][agent_y] = 'A'  # Mark the agent's position with 'A'
    grid[goal_x][goal_y] = 'G'  # Mark the goal position with 'G'
    grid[hole_x][hole_y] = 'H'  # Mark the hole position with 'H'

    # Print the current state, reward received, if the episode is done, and any additional info
    print(f"Step {step + 1}: State: {obs}, Reward: {rewards}, Done: {done}, Info: {info}")

    # Print the grid visually in the console
    print("+---" * 3 + "+")  # Top border of the grid
    for row in grid:
        print("|" + "|".join(f" {cell} " for cell in row) + "|")  # Print each row with cells separated by '|'
        print("+---" * 3 + "+")  # Separator border after each row

    # If the episode is finished (either the goal is reached or the agent fell into the hole), reset the environment
    if done:
        print(f"\nEpisode finished at step {step + 1}!")
        obs, info = env.reset()
        print("Environment reset for a new episode.\n")
# Out:
# Step 1: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 2: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 3: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 4: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 4!
# Environment reset for a new episode.
#
# Step 5: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 6: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 7: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 8: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 8!
# Environment reset for a new episode.
#
# Step 9: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 10: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 11: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 12: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 12!
# Environment reset for a new episode.
#
# Step 13: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 14: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 15: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 16: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 16!
# Environment reset for a new episode.
#
# Step 17: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 18: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 19: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 20: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 20!
# Environment reset for a new episode.
#
# Step 21: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 22: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 23: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 24: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 24!
# Environment reset for a new episode.
#
# Step 25: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 26: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 27: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 28: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 28!
# Environment reset for a new episode.
#
# Step 29: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 30: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 31: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 32: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 32!
# Environment reset for a new episode.
#
# Step 33: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 34: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 35: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 36: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 36!
# Environment reset for a new episode.
#
# Step 37: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 38: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 39: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 40: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 40!
# Environment reset for a new episode.
#
# Step 41: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 42: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 43: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 44: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 44!
# Environment reset for a new episode.
#
# Step 45: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 46: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 47: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 48: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 48!
# Environment reset for a new episode.
#
# Step 49: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 50: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 51: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 52: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 52!
# Environment reset for a new episode.
#
# Step 53: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 54: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 55: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 56: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 56!
# Environment reset for a new episode.
#
# Step 57: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 58: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 59: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 60: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 60!
# Environment reset for a new episode.
#
# Step 61: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 62: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 63: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 64: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 64!
# Environment reset for a new episode.
#
# Step 65: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 66: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 67: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 68: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 68!
# Environment reset for a new episode.
#
# Step 69: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 70: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 71: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 72: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 72!
# Environment reset for a new episode.
#
# Step 73: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 74: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 75: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 76: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 76!
# Environment reset for a new episode.
#
# Step 77: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 78: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 79: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 80: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 80!
# Environment reset for a new episode.
#
# Step 81: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 82: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 83: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 84: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 84!
# Environment reset for a new episode.
#
# Step 85: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 86: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 87: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 88: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 88!
# Environment reset for a new episode.
#
# Step 89: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 90: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 91: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 92: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 92!
# Environment reset for a new episode.
#
# Step 93: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 94: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 95: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 96: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 96!
# Environment reset for a new episode.
#
# Step 97: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 98: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 99: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 100: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 100!
# Environment reset for a new episode.
#
# Step 101: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 102: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 103: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 104: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 104!
# Environment reset for a new episode.
#
# Step 105: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 106: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 107: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 108: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 108!
# Environment reset for a new episode.
#
# Step 109: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 110: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 111: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 112: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 112!
# Environment reset for a new episode.
#
# Step 113: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 114: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 115: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 116: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 116!
# Environment reset for a new episode.
#
# Step 117: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 118: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 119: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 120: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 120!
# Environment reset for a new episode.
#
# Step 121: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 122: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 123: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 124: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 124!
# Environment reset for a new episode.
#
# Step 125: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 126: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 127: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 128: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 128!
# Environment reset for a new episode.
#
# Step 129: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 130: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 131: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 132: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 132!
# Environment reset for a new episode.
#
# Step 133: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 134: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 135: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 136: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 136!
# Environment reset for a new episode.
#
# Step 137: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 138: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 139: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 140: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 140!
# Environment reset for a new episode.
#
# Step 141: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 142: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 143: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 144: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 144!
# Environment reset for a new episode.
#
# Step 145: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 146: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 147: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 148: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 148!
# Environment reset for a new episode.
#
# Step 149: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 150: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 151: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 152: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 152!
# Environment reset for a new episode.
#
# Step 153: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 154: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 155: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 156: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 156!
# Environment reset for a new episode.
#
# Step 157: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 158: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 159: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 160: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 160!
# Environment reset for a new episode.
#
# Step 161: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 162: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 163: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 164: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 164!
# Environment reset for a new episode.
#
# Step 165: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 166: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 167: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 168: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 168!
# Environment reset for a new episode.
#
# Step 169: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 170: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 171: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 172: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 172!
# Environment reset for a new episode.
#
# Step 173: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 174: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 175: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 176: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 176!
# Environment reset for a new episode.
#
# Step 177: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 178: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 179: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 180: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 180!
# Environment reset for a new episode.
#
# Step 181: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 182: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 183: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 184: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 184!
# Environment reset for a new episode.
#
# Step 185: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 186: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 187: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 188: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 188!
# Environment reset for a new episode.
#
# Step 189: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 190: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 191: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 192: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 192!
# Environment reset for a new episode.
#
# Step 193: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 194: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 195: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 196: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 196!
# Environment reset for a new episode.
#
# Step 197: State: {'agent': array([1, 0]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 3}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# | A |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 198: State: {'agent': array([1, 1]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 2}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | A |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 199: State: {'agent': array([1, 2]), 'target': array([2, 2], dtype=int32)}, Reward: -1, Done: False, Info: {'distance': 1}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   | A |
# +---+---+---+
# |   | H | G |
# +---+---+---+
# Step 200: State: {'agent': array([2, 2]), 'target': array([2, 2], dtype=int32)}, Reward: 10, Done: True, Info: {'distance': 0}
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   |   |   |
# +---+---+---+
# |   | H | G |
# +---+---+---+
#
# Episode finished at step 200!
# Environment reset for a new episode.
